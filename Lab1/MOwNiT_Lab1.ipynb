# %% [markdown]
# # MOwNiT – arytmetyka komputerowa

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
k = 45
p = 3

# %%
def visualize(points1, points2):
    plt.figure(figsize=(12,6))
    plt.xlabel("X[k]")
    plt.ylabel("values")
    plt.plot(points1, marker="o", markersize=5, label="Double")
    plt.plot(points2, marker="o", markersize=5, label="Longdouble")
    plt.legend()
    plt.show()

# %%
def visualize2(points1, points2):
    df = pd.DataFrame({'Forward': points1, 'Backward': points2})
    display(df)

# %%
def visualize3(float_points1, float_points2, double_points1, dobule_points2, longdouble_points1, longdouble_points2):
    df = pd.DataFrame(
        {'Forward float': float_points1, 'Backward float': float_points2, 'Forward double': double_points1,
         'Backward double': dobule_points2, 'Forward long double': longdouble_points1,
         'Backward long double': longdouble_points2})
    display(df)

# %%
def visualize4(points1,points2,points3):
    plt.figure(figsize=(12,6))
    plt.xlabel("X[k]")
    plt.ylabel("values")
    plt.plot(points1, marker="o", markersize=5, label="Float32")
    plt.plot(points2, marker="o", markersize=5, label="Double")
    plt.plot(points3, marker="o", markersize=5, label="Longdouble")
    plt.legend()
    plt.show()

# %% [markdown]
# # Inforamcje o typach danych:

# %%
print(np.finfo(np.float32))
# Out:
# Machine parameters for float32
# ---------------------------------------------------------------
# precision =   6   resolution = 1.0000000e-06
# machep =    -23   eps =        1.1920929e-07
# negep =     -24   epsneg =     5.9604645e-08
# minexp =   -126   tiny =       1.1754944e-38
# maxexp =    128   max =        3.4028235e+38
# nexp =        8   min =        -max
# smallest_normal = 1.1754944e-38   smallest_subnormal = 1.4012985e-45
# ---------------------------------------------------------------

# %%
print(np.finfo(np.double))
# Out:
# Machine parameters for float64
# ---------------------------------------------------------------
# precision =  15   resolution = 1.0000000000000001e-15
# machep =    -52   eps =        2.2204460492503131e-16
# negep =     -53   epsneg =     1.1102230246251565e-16
# minexp =  -1022   tiny =       2.2250738585072014e-308
# maxexp =   1024   max =        1.7976931348623157e+308
# nexp =       11   min =        -max
# smallest_normal = 2.2250738585072014e-308   smallest_subnormal = 4.9406564584124654e-324
# ---------------------------------------------------------------

# %%
print(np.finfo(np.longdouble))
# Out:
# Machine parameters for float64
# ---------------------------------------------------------------
# precision =  15   resolution = 1.0000000000000001e-15
# machep =    -52   eps =        2.2204460492503131e-16
# negep =     -53   epsneg =     1.1102230246251565e-16
# minexp =  -1022   tiny =       2.2250738585072014e-308
# maxexp =   1024   max =        1.7976931348623157e+308
# nexp =       11   min =        -max
# smallest_normal = 2.2250738585072014e-308   smallest_subnormal = 4.9406564584124654e-324
# ---------------------------------------------------------------

# %% [markdown]
# # Typ liczb float:

# %%
def float_sequence(k, p):
    arr = [0 for _ in range(k + 2)]
    arr[0],arr[1] = np.float32(1),np.float32(1 / p)
    for i in range(2, k + 2):
        arr[i] = np.float32((1 / p) * (10 * arr[i - 1] - p * arr[i - 2]))

    arrBack = [0 for _ in range(k + 2)]
    arrBack[k],arrBack[k + 1] = arr[k],arr[k + 1]
    for i in range(k - 1, -1, -1):
        arrBack[i] = np.float32((1 / p) * (10 * arrBack[i + 1] - p * arrBack[i + 2]))
    return arr,arrBack

# %%
float32_arr,float32_back = float_sequence(k,p)

# %%
visualize2(float32_arr,float32_back)
# Out:
#          Forward      Backward
# 0   1.000000e+00 -1.258582e+27
# 1   3.333333e-01 -4.195273e+26
# 2   1.111111e-01 -1.398424e+26
# 3   3.703713e-02 -4.661414e+25
# 4   1.234596e-02 -1.553805e+25
# 5   4.116068e-03 -5.179348e+24
# 6   1.374266e-03 -1.726449e+24
# 7   4.648194e-04 -5.754831e+23
# 8   1.751318e-04 -1.918277e+23
# 9   1.189533e-04 -6.394257e+22
# 10  2.213791e-04 -2.131419e+22
# 11  6.189770e-04 -7.104730e+21
# 12  1.841878e-03 -2.368243e+21
# 13  5.520615e-03 -7.894145e+20
# 14  1.656017e-02 -2.631382e+20
# 15  4.967995e-02 -8.771272e+19
# 16  1.490397e-01 -2.923757e+19
# 17  4.471189e-01 -9.745858e+18
# 18  1.341357e+00 -3.248619e+18
# 19  4.024070e+00 -1.082873e+18
# 20  1.207221e+01 -3.609577e+17
# 21  3.621663e+01 -1.203192e+17
# 22  1.086499e+02 -4.010641e+16
# 23  3.259496e+02 -1.336880e+16
# 24  9.778489e+02 -4.456268e+15
# 25  2.933547e+03 -1.485423e+15
# 26  8.800641e+03 -4.951409e+14
# 27  2.640192e+04 -1.650470e+14
# 28  7.920577e+04 -5.501565e+13
# 29  2.376173e+05 -1.833855e+13
# 30  7.128519e+05 -6.112849e+12
# 31  2.138556e+06 -2.037615e+12
# 32  6.415666e+06 -6.791991e+11
# 33  1.924700e+07 -2.263826e+11
# 34  5.774100e+07 -7.540954e+10
# 35  1.732230e+08 -2.498254e+10
# 36  5.196690e+08 -7.865585e+09
# 37  1.559007e+09 -1.236078e+09
# 38  4.677021e+09  3.745326e+09
# 39  1.403106e+10  1.372050e+10
# 40  4.209319e+10  4.198966e+10
# 41  1.262796e+11  1.262451e+11
# 42  3.788387e+11  3.788272e+11
# 43  1.136516e+12  1.136512e+12
# 44  3.409548e+12  3.409547e+12
# 45  1.022864e+13  1.022864e+13
# 46  3.068593e+13  3.068593e+13

# %% [markdown]
# # Typ liczb double:

# %%
def double_sequence(k, p):
    arr = [0 for _ in range(k + 2)]
    arr[0],arr[1] = np.double(1),np.double(1 / p)
    for i in range(2, k + 2):
        arr[i] = np.double((1 / p) * (10 * arr[i - 1] - p * arr[i - 2]))

    arrBack = [0 for _ in range(k + 2)]
    arrBack[k],arrBack[k + 1] = arr[k],arr[k + 1]
    for i in range(k - 1, -1, -1):
        arrBack[i] = np.double((1 / p) * (10 * arrBack[i + 1] - p * arrBack[i + 2]))
    return arr,arrBack

# %%
double_arr,double_back = double_sequence(k,p)

# %%
visualize2(double_arr,double_back)
# Out:
#          Forward      Backward
# 0   1.000000e+00 -2.466985e+10
# 1   3.333333e-01 -8.223285e+09
# 2   1.111111e-01 -2.741095e+09
# 3   3.703704e-02 -9.136983e+08
# 4   1.234568e-02 -3.045661e+08
# 5   4.115226e-03 -1.015220e+08
# 6   1.371742e-03 -3.384068e+07
# 7   4.572474e-04 -1.128023e+07
# 8   1.524158e-04 -3.760075e+06
# 9   5.080526e-05 -1.253358e+06
# 10  1.693509e-05 -4.177862e+05
# 11  5.645027e-06 -1.392621e+05
# 12  1.881669e-06 -4.642068e+04
# 13  6.272038e-07 -1.547356e+04
# 14  2.090103e-07 -5.157854e+03
# 15  6.949709e-08 -1.719285e+03
# 16  2.264668e-08 -5.730949e+02
# 17  5.991855e-09 -1.910316e+02
# 18 -2.673835e-09 -6.367721e+01
# 19 -1.490464e-08 -2.122574e+01
# 20 -4.700829e-08 -7.075245e+00
# 21 -1.417897e-07 -2.358415e+00
# 22 -4.256239e-07 -7.861388e-01
# 23 -1.276957e-06 -2.620474e-01
# 24 -3.830898e-06 -8.735254e-02
# 25 -1.149270e-05 -2.912773e-02
# 26 -3.447812e-05 -9.739890e-03
# 27 -1.034343e-04 -3.338572e-03
# 28 -3.103030e-04 -1.388682e-03
# 29 -9.309091e-04 -1.290369e-03
# 30 -2.792727e-03 -2.912547e-03
# 31 -8.378182e-03 -8.418122e-03
# 32 -2.513455e-02 -2.514786e-02
# 33 -7.540364e-02 -7.540808e-02
# 34 -2.262109e-01 -2.262124e-01
# 35 -6.786328e-01 -6.786333e-01
# 36 -2.035898e+00 -2.035898e+00
# 37 -6.107695e+00 -6.107695e+00
# 38 -1.832308e+01 -1.832308e+01
# 39 -5.496925e+01 -5.496925e+01
# 40 -1.649078e+02 -1.649078e+02
# 41 -4.947233e+02 -4.947233e+02
# 42 -1.484170e+03 -1.484170e+03
# 43 -4.452510e+03 -4.452510e+03
# 44 -1.335753e+04 -1.335753e+04
# 45 -4.007259e+04 -4.007259e+04
# 46 -1.202178e+05 -1.202178e+05

# %% [markdown]
# #  Typ liczb longdouble:

# %%
def longdouble_sequence(k, p):
    arr = [0 for _ in range(k + 2)]
    arr[0],arr[1] = np.longdouble(1),np.longdouble(1 / p)
    for i in range(2, k + 2):
        arr[i] = np.longdouble((1 / p) * (10 * arr[i - 1] - p * arr[i - 2]))

    arrBack = [0 for _ in range(k + 2)]
    arrBack[k],arrBack[k + 1] = arr[k],arr[k + 1]
    for i in range(k - 1, -1, -1):
        arrBack[i] = np.longdouble((1 / p) * (10 * arrBack[i + 1] - p * arrBack[i + 2]))

    return arr,arrBack

# %%
longdouble_arr,longdouble_back = longdouble_sequence(k,p)

# %%
visualize2(longdouble_arr,longdouble_back)
# Out:
#          Forward      Backward
# 0   1.000000e+00 -2.466985e+10
# 1   3.333333e-01 -8.223285e+09
# 2   1.111111e-01 -2.741095e+09
# 3   3.703704e-02 -9.136983e+08
# 4   1.234568e-02 -3.045661e+08
# 5   4.115226e-03 -1.015220e+08
# 6   1.371742e-03 -3.384068e+07
# 7   4.572474e-04 -1.128023e+07
# 8   1.524158e-04 -3.760075e+06
# 9   5.080526e-05 -1.253358e+06
# 10  1.693509e-05 -4.177862e+05
# 11  5.645027e-06 -1.392621e+05
# 12  1.881669e-06 -4.642068e+04
# 13  6.272038e-07 -1.547356e+04
# 14  2.090103e-07 -5.157854e+03
# 15  6.949709e-08 -1.719285e+03
# 16  2.264668e-08 -5.730949e+02
# 17  5.991855e-09 -1.910316e+02
# 18 -2.673835e-09 -6.367721e+01
# 19 -1.490464e-08 -2.122574e+01
# 20 -4.700829e-08 -7.075245e+00
# 21 -1.417897e-07 -2.358415e+00
# 22 -4.256239e-07 -7.861388e-01
# 23 -1.276957e-06 -2.620474e-01
# 24 -3.830898e-06 -8.735254e-02
